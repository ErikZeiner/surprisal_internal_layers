# %% [markdown]
# # Set-up

# %%
from google.colab import drive
import os

drive.mount('/content/gdrive/')
os.chdir('/content/gdrive/My Drive/Colab Notebooks/Internship/surprisal_internal_layers_shared/')

# !cd ..
# !pip install -r requirements.txt
# !pip install transformers tuned_lens
# !pip install bitsandbytes
# Out:
# Mounted at /content/gdrive/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 74.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.2/155.2 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.4/427.4 kB 15.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 23.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.2/152.2 kB 15.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### Overview of sucessful runs
#
# | Model | DC | Fillers | M_N400 | MECO | NS | S_N400 | UCL | ZuCO|
# |---|---|---|---|---|---|---|---|---|
# | gpt2 |O|O|O|-|O|O|O|O|
# | gpt2-medium |O|O|O|-|O|O|O|O|
# | gpt2-large |O|O|O|-|O|O|O|O|
# | gpt2-xl |O|O|O|-|O|O|O|O|
# | facebook/opt-125m |O||||||||
# | facebook/opt-1.3b |O||||||||
# | facebook/opt-2.7b ||X|||||||
# | facebook/opt-6.7b ||X|||||||
# | facebook/opt-13b |||||||||
# | facebook/opt-30b |||||||||
# | facebook/opt-66b |||||||||
# | EleutherAI/pythia-70m-deduped |O||||||||
# | EleutherAI/pythia-160m-deduped |O||||||||
# | EleutherAI/pythia-410m-deduped |O||||||||
# | EleutherAI/pythia-1b-deduped-v0 |O||||||||
# | EleutherAI/pythia-1.4b-deduped |O||||||||
# | EleutherAI/pythia-2.8b-deduped |O||||||||
# | EleutherAI/pythia-6.9b-deduped |||||||||
# | EleutherAI/pythia-12b-deduped |||||||||
# |FOR MECO v|---|---|---|---|---|---|---|---|
# | facebook/xglm-564M |||||||||
# | facebook/xglm-1.7B |||||||||
# | facebook/xglm-2.9B |||||||||
# | facebook/xglm-4.5B |||||||||
# | facebook/xglm-7.5B |||||||||
#
# #### Overview of sucessful runs - tuned lens
# | Model | DC | Fillers | M_N400 | MECO | NS | S_N400 | UCL | ZuCO|
# |---|---|---|---|---|---|---|---|---|
# | gpt2 |||||||||
# | gpt2-medium |||||||||
# | gpt2-large |||||||||
# | gpt2-xl |||||||||
# | facebook/opt-125m |||||||||
# | facebook/opt-1.3b |||||||||
# | facebook/opt-2.7b |||||||||
# | facebook/opt-6.7b |||||||||
# | facebook/opt-13b |||||||||
# | facebook/opt-30b |||||||||
# | facebook/opt-66b |||||||||
# | EleutherAI/pythia-70m-deduped |||||||||
# | EleutherAI/pythia-160m-deduped |||||||||
# | EleutherAI/pythia-410m-deduped |||||||||
# | EleutherAI/pythia-1b-deduped-v0 |||||||||
# | EleutherAI/pythia-1.4b-deduped |||||||||
# | EleutherAI/pythia-2.8b-deduped |||||||||
# | EleutherAI/pythia-6.9b-deduped |||||||||
# | EleutherAI/pythia-12b-deduped |||||||||

# %% [markdown]
# ## GPT-2

# %%
# !python src/run_gpt2.py -m gpt2 -d DC
# Out:
# 2025-06-28 12:36:37.362642: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751114197.380081    3159 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751114197.386114    3159 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-28 12:36:37.406032: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m gpt2 -d DC
# !python src/run_gpt2.py -m gpt2-medium -d DC
# !python src/run_gpt2.py -m gpt2-large -d DC
# !python src/run_gpt2.py -m gpt2-xl -d DC
# Out:
# 2025-05-25 13:38:39.274718: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748180319.526915    4222 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748180319.593858    4222 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-25 13:38:40.124657: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m gpt2 -d Fillers
# !python src/run_gpt2.py -m gpt2-medium -d Fillers
# !python src/run_gpt2.py -m gpt2-large -b 2 -d Fillers
# !python src/run_gpt2.py -m gpt2-xl -b 2 -d Fillers
# Out:
# 2025-05-24 13:54:08.568062: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748094848.601575   12047 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748094848.612092   12047 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-24 13:54:08.645341: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m gpt2 -d M_N400
# !python src/run_gpt2.py -m gpt2-medium -d M_N400
# !python src/run_gpt2.py -m gpt2-large -b 2 -d M_N400
# !python src/run_gpt2.py -m gpt2-xl -b 2 -d M_N400
# Out:
# 2025-05-24 14:11:45.234145: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748095905.271187   16414 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748095905.281950   16414 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-24 14:11:45.316442: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m gpt2 -d NS
# !python src/run_gpt2.py -m gpt2-medium -d NS
# !python src/run_gpt2.py -m gpt2-large -b 2 -d NS
# !python src/run_gpt2.py -m gpt2-xl -b 2 -d NS
# Out:
# 2025-05-24 14:21:51.057184: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748096511.077202   19020 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748096511.083301   19020 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-24 14:21:51.105795: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m gpt2 -d S_N400
# !python src/run_gpt2.py -m gpt2-medium -d S_N400
# !python src/run_gpt2.py -m gpt2-large -b 2 -d S_N400
# !python src/run_gpt2.py -m gpt2-xl -b 2 -d S_N400
# Out:
# Streaming output truncated to the last 5000 lines.
# 172
# 100% 1/1 [00:00<00:00,  8.71it/s]
# 173
# 100% 1/1 [00:00<00:00,  5.82it/s]
# 174
# 100% 1/1 [00:00<00:00,  8.69it/s]
# 175
# 100% 1/1 [00:00<00:00,  7.62it/s]
# 176
# 100% 1/1 [00:00<00:00,  6.58it/s]
# 177
# 100% 1/1 [00:00<00:00,  8.61it/s]
# 178
# 100% 1/1 [00:00<00:00,  7.52it/s]
# 179
# 100% 1/1 [00:00<00:00,  7.16it/s]
# 180
# 100% 1/1 [00:00<00:00,  8.89it/s]
# 181
# 100% 1/1 [00:00<00:00,  6.43it/s]
# 182
# 100% 1/1 [00:00<00:00,  6.82it/s]
# 183
# 100% 1/1 [00:00<00:00,  6.45it/s]
# 184
# 100% 1/1 [00:00<00:00,  8.04it/s]
# 185
# 100% 1/1 [00:00<00:00,  4.86it/s]
# 186
# 100% 1/1 [00:00<00:00,  7.06it/s]
# 187
# 100% 1/1 [00:00<00:00,  7.99it/s]
# 188
# 100% 1/1 [00:00<00:00,  9.24it/s]
# 189
# 100% 1/1 [00:00<00:00,  8.35it/s]
# 190
# 100% 1/1 [00:00<00:00,  6.26it/s]
# 191
# 100% 1/1 [00:00<00:00,  7.01it/s]
# 192
# 100% 1/1 [00:00<00:00,  5.49it/s]
# 193
# 100% 1/1 [00:00<00:00,  8.62it/s]
# 194
# ...

# %%
# !python src/run_gpt2.py -m gpt2 -d UCL
# !python src/run_gpt2.py -m gpt2-medium -d UCL
# !python src/run_gpt2.py -m gpt2-large -b 2 -d UCL
# !python src/run_gpt2.py -m gpt2-xl -b 2 -d UCL
# Out:
# 2025-05-24 14:52:24.514007: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748098344.535875   26915 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748098344.542048   26915 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-24 14:52:24.563282: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m gpt2 -d ZuCO
# !python src/run_gpt2.py -m gpt2-medium -d ZuCO
# !python src/run_gpt2.py -m gpt2-large -b 2 -d ZuCO
# !python src/run_gpt2.py -m gpt2-xl -b 2 -d ZuCO
# Out:
# 2025-05-24 14:57:16.467021: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748098636.502338   28209 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748098636.515919   28209 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-24 14:57:16.550650: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## Pythia

# %%
# !python src/run_gpt2.py -m EleutherAI/pythia-70m-deduped -d DC
# !python src/run_gpt2.py -m EleutherAI/pythia-160m-deduped -d DC
# !python src/run_gpt2.py -m EleutherAI/pythia-410m-deduped -d DC
# !python src/run_gpt2.py -m EleutherAI/pythia-1b-deduped -d DC
# !python src/run_gpt2.py -m EleutherAI/pythia-1.4b-deduped -d DC
# !python src/run_gpt2.py -m EleutherAI/pythia-2.8b-deduped -d DC
# !python src/run_gpt2.py -m EleutherAI/pythia-6.9b-deduped -d DC
# !python src/run_gpt2.py -m EleutherAI/pythia-12b-deduped -d DC
# Out:
# Streaming output truncated to the last 5000 lines.
#
# pytorch_model-00002-of-00002.bin:  64% 2.52G/3.94G [01:50<00:59, 24.0MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.69G/9.91G [01:51<04:56, 24.3MB/s]
#
# pytorch_model-00002-of-00002.bin:  64% 2.53G/3.94G [01:51<00:58, 24.0MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.71G/9.91G [01:51<04:57, 24.3MB/s]
#
# pytorch_model-00002-of-00002.bin:  64% 2.54G/3.94G [01:51<00:58, 24.0MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.72G/9.91G [01:52<04:55, 24.3MB/s]
#
# pytorch_model-00002-of-00002.bin:  65% 2.55G/3.94G [01:52<00:57, 24.1MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.73G/9.91G [01:52<04:55, 24.3MB/s]
#
# pytorch_model-00002-of-00002.bin:  65% 2.56G/3.94G [01:52<00:57, 24.0MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.74G/9.91G [01:52<04:55, 24.3MB/s]
#
# pytorch_model-00002-of-00002.bin:  65% 2.57G/3.94G [01:52<00:56, 24.1MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.75G/9.91G [01:53<04:55, 24.2MB/s]
#
# ...

# %%
# !python src/run_gpt2.py -m EleutherAI/pythia-70m-deduped -d Fillers
# !python src/run_gpt2.py -m EleutherAI/pythia-160m-deduped -d Fillers
# !python src/run_gpt2.py -m EleutherAI/pythia-410m-deduped -d Fillers
# !python src/run_gpt2.py -m EleutherAI/pythia-1b-deduped -d Fillers
# !python src/run_gpt2.py -m EleutherAI/pythia-1.4b-deduped -d Fillers
# !python src/run_gpt2.py -m EleutherAI/pythia-2.8b-deduped -d Fillers
# !python src/run_gpt2.py -m EleutherAI/pythia-6.9b-deduped -d Fillers
# !python src/run_gpt2.py -m EleutherAI/pythia-12b-deduped -d Fillers
# Out:
# 2025-05-12 21:05:36.925842: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747083936.946205   10748 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747083936.952361   10748 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12 21:05:36.973188: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m EleutherAI/pythia-6.9b-deduped -d Fillers
# Out:
# 2025-06-01 13:48:43.508237: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748785723.718574    7843 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748785723.773538    7843 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-01 13:48:44.296680: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m EleutherAI/pythia-70m-deduped -d M_N400
# !python src/run_gpt2.py -m EleutherAI/pythia-160m-deduped -d M_N400
# !python src/run_gpt2.py -m EleutherAI/pythia-410m-deduped -d M_N400
# !python src/run_gpt2.py -m EleutherAI/pythia-1b-deduped -d M_N400
# !python src/run_gpt2.py -m EleutherAI/pythia-1.4b-deduped -d M_N400
# !python src/run_gpt2.py -m EleutherAI/pythia-2.8b-deduped -d M_N400
# !python src/run_gpt2.py -m EleutherAI/pythia-6.9b-deduped -d M_N400
# !python src/run_gpt2.py -m EleutherAI/pythia-12b-deduped -d M_N400

# %%
# !python src/run_gpt2.py -m EleutherAI/pythia-70m-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-160m-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-410m-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-1b-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-1.4b-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-2.8b-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-6.9b-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-12b-deduped -d NS

# %%
# !python src/run_gpt2.py -m EleutherAI/pythia-70m-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-160m-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-410m-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-1b-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-1.4b-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-2.8b-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-6.9b-deduped -d NS
# !python src/run_gpt2.py -m EleutherAI/pythia-12b-deduped -d NS
# Out:
# python3: can't open file '/content/src/run_gpt2.py': [Errno 2] No such file or directory
# python3: can't open file '/content/src/run_gpt2.py': [Errno 2] No such file or directory

# %%
# !python src/run_gpt2.py -m EleutherAI/pythia-70m-deduped -d UCL
# !python src/run_gpt2.py -m EleutherAI/pythia-160m-deduped -d UCL
# !python src/run_gpt2.py -m EleutherAI/pythia-410m-deduped -d UCL
# !python src/run_gpt2.py -m EleutherAI/pythia-1b-deduped -d UCL
# !python src/run_gpt2.py -m EleutherAI/pythia-1.4b-deduped -d UCL
# !python src/run_gpt2.py -m EleutherAI/pythia-2.8b-deduped -d UCL
# !python src/run_gpt2.py -m EleutherAI/pythia-6.9b-deduped -d UCL
# !python src/run_gpt2.py -m EleutherAI/pythia-12b-deduped -d UCL

# %%
# !python src/run_gpt2.py -m EleutherAI/pythia-70m-deduped -d ZuCO
# !python src/run_gpt2.py -m EleutherAI/pythia-160m-deduped -d ZuCO
# !python src/run_gpt2.py -m EleutherAI/pythia-410m-deduped -d ZuCO
# !python src/run_gpt2.py -m EleutherAI/pythia-1b-deduped-v0 -d ZuCO
# !python src/run_gpt2.py -m EleutherAI/pythia-1.4b-deduped -d ZuCO
# !python src/run_gpt2.py -m EleutherAI/pythia-2.8b-deduped -d ZuCO
# !python src/run_gpt2.py -m EleutherAI/pythia-6.9b-deduped -d ZuCO -q 8bit
# !python src/run_gpt2.py -m EleutherAI/pythia-12b-deduped -d ZuCO -q 8bit

# %% [markdown]
# ## OPT

# %% [markdown]
# ### Small models

# %%
# !python src/run_gpt2.py -m facebook/opt-125m
# !python src/run_gpt2.py -m facebook/opt-1.3b
# Out:
# 2025-05-25 17:30:09.309380: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748194209.569332    3406 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748194209.640726    3406 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-25 17:30:10.196170: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pip install huggingface_hub[hf_xet]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 24.9 MB/s eta 0:00:00
# ...

# %%
# !python src/run_gpt2.py -m facebook/opt-2.7b -d Fillers
# Out:
# 2025-05-25 16:04:19.209936: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748189059.435227    2767 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748189059.498979    2767 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-25 16:04:19.977726: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python src/run_gpt2.py -m facebook/opt-6.7b -d Fillers

# %%
# !python src/run_gpt2.py -m facebook/opt-125m -d M_N400
# !python src/run_gpt2.py -m facebook/opt-1.3b -d M_N400
# !python src/run_gpt2.py -m facebook/opt-2.7b -d M_N400
# !python src/run_gpt2.py -m facebook/opt-6.7b -d M_N400

# %%
# !for lang in du ee en fi ge gr he it ko no ru sp tr
# !do
    # !echo "Processing $lang"
    # !python src/run_gpt2.py  -m facebook/xglm-564M -d MECO/$lang
    # !pythdon src/run_gpt2.py  -m facebook/xglm-1.7B -d MECO/$lang
    # !python src/run_gpt2.py  -m facebook/xglm-2.9B -d MECO/$lang
    # !python src/run_gpt2.py  -m facebook/xglm-4.5B -d MECO/$lang
    # !python src/run_gpt2.py  -m facebook/xglm-7.5B -d MECO/$lang
# !done

# %%
# !python src/run_gpt2.py -m facebook/opt-125m -d NS
# !python src/run_gpt2.py -m facebook/opt-1.3b -d NS
# !python src/run_gpt2.py -m facebook/opt-2.7b -d NS
# !python src/run_gpt2.py -m facebook/opt-6.7b -d NS

# %%
# !python src/run_gpt2.py -m facebook/opt-125m -d S_N400
# !python src/run_gpt2.py -m facebook/opt-1.3b -d S_N400
# !python src/run_gpt2.py -m facebook/opt-2.7b -d S_N400
# !python src/run_gpt2.py -m facebook/opt-6.7b -d S_N400

# %%
# !python src/run_gpt2.py -m facebook/opt-125m -d UCL
# !python src/run_gpt2.py -m facebook/opt-1.3b -d UCL
# !python src/run_gpt2.py -m facebook/opt-2.7b -d UCL
# !python src/run_gpt2.py -m facebook/opt-6.7b -d UCL

# %%
# !python src/run_gpt2.py -m facebook/opt-125m -d ZuCO
# !python src/run_gpt2.py -m facebook/opt-1.3b -d ZuCO
# !python src/run_gpt2.py -m facebook/opt-2.7b -d ZuCO
# !python src/run_gpt2.py -m facebook/opt-6.7b -d ZuCO

# %% [markdown]
# ### Large models

# %%
# !python src/run_gpt2.py -m facebook/opt-13b -q 8bit
# !python src/run_gpt2.py -m facebook/opt-30b -q 8bit
# !python src/run_gpt2.py -m facebook/opt-66b -q 4bit

# %% [markdown]
# ## General

# %%
# !python src/modeling_reading_time.py -i results/logit-lens/DC -d DC -o
# Out:
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/Colab Notebooks/Internship/surprisal_internal_layers_shared/src/modeling_reading_time.py", line 6, in <module>
#     import statsmodels.api as sm
#   File "/usr/local/lib/python3.11/dist-packages/statsmodels/api.py", line 81, in <module>
#     from .discrete.conditional_models import (
#   File "/usr/local/lib/python3.11/dist-packages/statsmodels/discrete/conditional_models.py", line 9, in <module>
#     from statsmodels.discrete.discrete_model import (MultinomialResults,
# KeyboardInterrupt
# ^C

# %%
# !python src/run_gpt2.py -m facebook/opt-66b -q 4bit
# Out:
# 2025-05-22 15:12:58.834384: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747926778.863824    6236 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747926778.875387    6236 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-22 15:12:58.920609: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # New section
